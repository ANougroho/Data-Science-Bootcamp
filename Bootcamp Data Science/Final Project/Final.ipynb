# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Data_Negara_HELP.csv")
df
# Out:
#                   Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 0            Afghanistan           90.2    10.0       7.58   44.9        1610
# 1                Albania           16.6    28.0       6.55   48.6        9930
# 2                Algeria           27.3    38.4       4.17   31.4       12900
# 3                 Angola          119.0    62.3       2.85   42.9        5900
# 4    Antigua and Barbuda           10.3    45.5       6.03   58.9       19100
# ..                   ...            ...     ...        ...    ...         ...
# 162              Vanuatu           29.2    46.6       5.25   52.7        2950
# 163            Venezuela           17.1    28.5       4.91   17.6       16500
# 164              Vietnam           23.3    72.0       6.84   80.2        4490
# 165                Yemen           56.3    30.0       5.18   34.4        4480
# 166               Zambia           83.1    37.0       5.89   30.9        3280
#
# ...

# %%
df.describe()
# Out:
#        Kematian_anak      Ekspor   Kesehatan       Impor     Pendapatan  \
# count     167.000000  167.000000  167.000000  167.000000     167.000000
# mean       38.270060   41.108976    6.815689   46.890215   17144.688623
# std        40.328931   27.412010    2.746837   24.209589   19278.067698
# min         2.600000    0.109000    1.810000    0.065900     609.000000
# 25%         8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%        19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%        62.100000   51.350000    8.600000   58.750000   22800.000000
# max       208.000000  200.000000   17.900000  174.000000  125000.000000
#
#           Inflasi  Harapan_hidup  Jumlah_fertiliti   GDPperkapita
# count  167.000000     167.000000        167.000000     167.000000
# mean     7.781832      70.555689          2.947964   12964.155689
# std     10.570704       8.893172          1.513848   18328.704809
# ...

# %%
df_gdp = df.sort_values('GDPperkapita', ascending=True)
df_gdp.head()
# Out:
#                Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 26            Burundi           93.6    8.92      11.60   39.2         764
# 88            Liberia           89.3   19.10      11.80   92.6         700
# 37   Congo, Dem. Rep.          116.0   41.10       7.91   49.6         609
# 112             Niger          123.0   22.20       5.16   49.1         814
# 132      Sierra Leone          160.0   16.80      13.10   34.5        1220
#
#      Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 26     12.30           57.7              6.26           231
# 88      5.47           60.8              5.02           327
# 37     20.80           57.5              6.54           334
# 112     2.55           58.8              7.49           348
# 132    17.20           55.0              5.20           399

# %%
sns.barplot(data=df_gdp, x="GDPperkapita", y="Negara")

# %%
df_inflasi = df.sort_values('Inflasi', ascending=False)
df_inflasi.head()
# Out:
#                 Negara  Kematian_anak  Ekspor  Kesehatan  Impor  Pendapatan  \
# 113            Nigeria          130.0    25.3       5.07   17.4        5150
# 163          Venezuela           17.1    28.5       4.91   17.6       16500
# 103           Mongolia           26.1    46.7       5.44   56.7        7710
# 149        Timor-Leste           62.6     2.2       9.12   27.8        1850
# 49   Equatorial Guinea          111.0    85.8       4.48   58.9       33700
#
#      Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 113    104.0           60.5              5.84          2330
# 163     45.9           75.4              2.47         13500
# 103     39.2           66.2              2.64          2650
# 149     26.5           71.1              6.23          3600
# 49      24.9           60.9              5.21         17100

# %%
sns.barplot(data=df_inflasi, x="Inflasi", y="Negara")

# %%
df_harapan = df.sort_values('Harapan_hidup', ascending=True)
df_harapan.head()
# Out:
#                        Negara  Kematian_anak  Ekspor  Kesehatan  Impor  \
# 66                      Haiti          208.0    15.3       6.91   64.7
# 87                    Lesotho           99.7    39.4      11.10  101.0
# 31   Central African Republic          149.0    11.8       3.98   26.5
# 166                    Zambia           83.1    37.0       5.89   30.9
# 94                     Malawi           90.5    22.8       6.59   34.9
#
#      Pendapatan  Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 66         1500     5.45           32.1              3.33           662
# 87         2380     4.15           46.5              3.30          1170
# 31          888     2.01           47.5              5.21           446
# 166        3280    14.00           52.0              5.40          1460
# 94         1030    12.10           53.1              5.31           459

# %%
sns.barplot(data=df_harapan, x="Harapan_hidup", y="Negara")

# %%
df_kematian = df.sort_values('Kematian_anak', ascending=False)
df_kematian.head()
# Out:
#                        Negara  Kematian_anak  Ekspor  Kesehatan  Impor  \
# 66                      Haiti          208.0    15.3       6.91   64.7
# 132              Sierra Leone          160.0    16.8      13.10   34.5
# 32                       Chad          150.0    36.8       4.53   43.5
# 31   Central African Republic          149.0    11.8       3.98   26.5
# 97                       Mali          137.0    22.8       4.98   35.1
#
#      Pendapatan  Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 66         1500     5.45           32.1              3.33           662
# 132        1220    17.20           55.0              5.20           399
# 32         1930     6.39           56.5              6.59           897
# 31          888     2.01           47.5              5.21           446
# 97         1870     4.37           59.5              6.55           708

# %%
df_pendapatan = df.sort_values('Pendapatan', ascending=True)
df_pendapatan.head()
# Out:
#                        Negara  Kematian_anak  Ekspor  Kesehatan  Impor  \
# 37           Congo, Dem. Rep.          116.0   41.10       7.91   49.6
# 88                    Liberia           89.3   19.10      11.80   92.6
# 26                    Burundi           93.6    8.92      11.60   39.2
# 112                     Niger          123.0   22.20       5.16   49.1
# 31   Central African Republic          149.0   11.80       3.98   26.5
#
#      Pendapatan  Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 37          609    20.80           57.5              6.54           334
# 88          700     5.47           60.8              5.02           327
# 26          764    12.30           57.7              6.26           231
# 112         814     2.55           58.8              7.49           348
# 31          888     2.01           47.5              5.21           446

# %%
sns.barplot(data=df_pendapatan, x="Pendapatan", y="Negara")

# %%
df_fertiliti = df.sort_values('Jumlah_fertiliti', ascending=True)
df_fertiliti.head()
# Out:
#                      Negara  Kematian_anak  Ekspor  Kesehatan  Impor  \
# 133               Singapore            2.8   200.0       3.96  174.0
# 138             South Korea            4.1    49.4       6.93   46.2
# 67                  Hungary            6.0    81.8       7.33   76.5
# 102                 Moldova           17.2    39.2      11.70   78.5
# 20   Bosnia and Herzegovina            6.9    29.7      11.10   51.3
#
#      Pendapatan  Inflasi  Harapan_hidup  Jumlah_fertiliti  GDPperkapita
# 133       72100   -0.046           82.7              1.15         46600
# 138       30400    3.160           80.1              1.23         22100
# 67        22300    2.330           74.5              1.25         13100
# 102        3910   11.100           69.7              1.27          1630
# 20         9720    1.400           76.8              1.31          4610

# %%
sns.barplot(data=df_fertiliti, x="Jumlah_fertiliti", y="Negara")

# %%
termiskin = pd.merge(pd.merge(df_gdp, df_pendapatan, on='Negara'),df_inflasi,on='Negara')
termiskin.head()
# Out:
#              Negara  Kematian_anak_x  Ekspor_x  Kesehatan_x  Impor_x  \
# 0           Burundi             93.6      8.92        11.60     39.2
# 1           Liberia             89.3     19.10        11.80     92.6
# 2  Congo, Dem. Rep.            116.0     41.10         7.91     49.6
# 3             Niger            123.0     22.20         5.16     49.1
# 4      Sierra Leone            160.0     16.80        13.10     34.5
#
#    Pendapatan_x  Inflasi_x  Harapan_hidup_x  Jumlah_fertiliti_x  \
# 0           764      12.30             57.7                6.26
# 1           700       5.47             60.8                5.02
# 2           609      20.80             57.5                6.54
# 3           814       2.55             58.8                7.49
# 4          1220      17.20             55.0                5.20
#
#    GDPperkapita_x  ...  GDPperkapita_y  Kematian_anak  Ekspor  Kesehatan  \
# 0             231  ...             231           93.6    8.92      11.60
# ...

# %%
sns.barplot(data=termiskin, x="GDPperkapita", y="Negara")

# %%
kesehatan_min = pd.merge(pd.merge(df_harapan, df_kematian, on='Negara'),df_fertiliti,on='Negara')
kesehatan_min.head()
# Out:
#                      Negara  Kematian_anak_x  Ekspor_x  Kesehatan_x  Impor_x  \
# 0                     Haiti            208.0      15.3         6.91     64.7
# 1                   Lesotho             99.7      39.4        11.10    101.0
# 2  Central African Republic            149.0      11.8         3.98     26.5
# 3                    Zambia             83.1      37.0         5.89     30.9
# 4                    Malawi             90.5      22.8         6.59     34.9
#
#    Pendapatan_x  Inflasi_x  Harapan_hidup_x  Jumlah_fertiliti_x  \
# 0          1500       5.45             32.1                3.33
# 1          2380       4.15             46.5                3.30
# 2           888       2.01             47.5                5.21
# 3          3280      14.00             52.0                5.40
# 4          1030      12.10             53.1                5.31
#
#    GDPperkapita_x  ...  GDPperkapita_y  Kematian_anak  Ekspor  Kesehatan  \
# ...

# %%
sns.barplot(data=kesehatan_min, x="Harapan_hidup", y="Negara")

# %%
negara_membutuhkan = pd.merge(termiskin, kesehatan_min, on='Negara')
negara_membutuhkan
# Out:
#              Negara  Kematian_anak_x_x  Ekspor_x_x  Kesehatan_x_x  Impor_x_x  \
# 0           Burundi               93.6        8.92          11.60       39.2
# 1           Liberia               89.3       19.10          11.80       92.6
# 2  Congo, Dem. Rep.              116.0       41.10           7.91       49.6
# 3             Niger              123.0       22.20           5.16       49.1
# 4      Sierra Leone              160.0       16.80          13.10       34.5
#
#    Pendapatan_x_x  Inflasi_x_x  Harapan_hidup_x_x  Jumlah_fertiliti_x_x  \
# 0             764        12.30               57.7                  6.26
# 1             700         5.47               60.8                  5.02
# 2             609        20.80               57.5                  6.54
# 3             814         2.55               58.8                  7.49
# 4            1220        17.20               55.0                  5.20
#
# ...

# %%
sns.barplot(data=negara_membutuhkan,x='GDPperkapita_y', y="Negara")
